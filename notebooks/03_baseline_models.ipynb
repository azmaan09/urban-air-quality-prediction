# %% [markdown]
# # 03 — Baseline Models
#
# Persistence, Logistic Regression, and Decision Tree with chronological splits.
#
# Authoritative metrics: `python scripts/train_evaluate.py` → `reports/tables/baseline_results.csv`

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))
import pandas as pd
from src.config import project_path
path = project_path("reports/tables/baseline_results.csv")
pd.read_csv(path) if path.exists() else print("Run scripts/train_evaluate.py first")
