# %% [markdown]
# # 04 — Advanced Models (XGBoost & LightGBM)
#
# Hyperparameters are selected using the validation window only (never the test set).

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))
import pandas as pd
from src.config import project_path
cmp = project_path("reports/tables/model_comparison.csv")
df = pd.read_csv(cmp) if cmp.exists() else None
df.sort_values(["split", "average_precision"], ascending=[True, False]) if df is not None else print("Run train_evaluate.py")
