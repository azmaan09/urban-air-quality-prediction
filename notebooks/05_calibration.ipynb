# %% [markdown]
# # 05 — Probability Calibration
#
# Early-warning systems need **reliable probabilities**, not only ranking metrics.
# Operators triage by risk; miscalibration causes alarm fatigue or missed events.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))
import pandas as pd
from IPython.display import Image, display
from src.config import project_path
path = project_path("reports/tables/calibration_results.csv")
display(pd.read_csv(path)) if path.exists() else print("Run train_evaluate.py")
for p in sorted(project_path("reports/figures").glob("reliability_*.png")):
    print(p.name); display(Image(filename=str(p)))
